# %% [markdown]
# # **Module 1: Programming Fundamentals for Machine Learning**
#
# ### **Prepared by**: Dr. Hum Nath Bhandari, Department of Mathematics, RWU
#
# ### **Course**: MATH 355/COMSC 415-Machine Learning
#
# ### **Notebook 6: Basic Seaborn Tutorial**
#
#
#
# ### **Overview**
#
# This notebook is a basic tutorial of Seaborn library, which is used for an advanced visualization in Python.
#
#
#
# ### Reference for This Material:
#
# - [Basic Seaborn Tutorial](https://seaborn.pydata.org/tutorial.html)
#
#
#
# ### **Learning Objectives**
#
# - Importing Seaborn library
# - Getting data directly from internet
# - Loading Seaborn datasets
# - Understanding some important plotting functions in python using Seaborn.
#
#
# ### Important Seaborn Functions
#
#    1. sns.barplot(): https://seaborn.pydata.org/generated/seaborn.barplot.html
#    2. sns.catplot(): https://seaborn.pydata.org/generated/seaborn.catplot.html
#    3. sns.scatterplot(): https://seaborn.pydata.org/generated/seaborn.scatterplot.html
#    4. sns.jointplot(): https://seaborn.pydata.org/generated/seaborn.jointplot.html
#    5. sns.kdeplot(): https://seaborn.pydata.org/generated/seaborn.kdeplot.html
#    6. sns.lineplot(): https://seaborn.pydata.org/generated/seaborn.lineplot.html
#    7. sns.heatmap(): https://seaborn.pydata.org/generated/seaborn.heatmap.html
#    8. sns.clustermap(): https://seaborn.pydata.org/generated/seaborn.clustermap.html
#    9. sns.boxplot(): https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### List of data sets in Seaborn

# %%
#sns.get_dataset_names()

# %% [markdown]
# ### Loading datasets from Seaborn

# %%
#tips = sns.load_dataset('tips')
#tips.head()

# %%
#titanic = sns.load_dataset('titanic')
#titanic.head()

# %%
#iris = sns.load_dataset('iris')
#iris

# %% [markdown]
# ### Visualizing Data

# %%
#tips.head()

# %% [markdown]
# ## Matplotlib VS Seaborn

# %%
#plt.plot(tips['total_bill'], tips['tip'], 'bo')
#plt.xlabel("total_bill")
#plt.ylabel("tips")

# %%
#sns.relplot(x = "total_bill", y = "tip", data = tips)

# %%
#sns.relplot(x="total_bill", y="tip", hue="smoker", data=tips)

# %%
#sns.relplot(x="total_bill", y="tip", hue="smoker", col = "time", data=tips)

# %%
#sns.relplot(x="total_bill", y="tip", hue="smoker", col = "sex", data=tips)

# %%
#sns.lmplot(x="total_bill", y="tip", col="time", hue="smoker",
#           data=tips);

# %%
#sns.catplot(x="day", y="total_bill", hue = "smoker",
#            kind ="swarm", data = tips);

# %%
#sns.catplot(x="day", y="total_bill", hue="sex", col = "time",
#            kind ='swarm', data=tips);

# %%
#sns.catplot(x="day", y="total_bill", hue="smoker",
#            kind= "strip", data=tips);

# %%
#sns.catplot(x="day", y="total_bill", hue="smoker",
#            kind="violin", split=True, data=tips);

# %%
#sns.catplot(x="day", y="total_bill", hue="smoker",
#            kind="box", data=tips);

# %%
#sns.catplot(x="day", y = "total_bill", hue ="smoker",
#            kind="bar", data=tips);

# %%
#iris = sns.load_dataset("iris")

#sns.pairplot(iris)

# %%
#sns.jointplot(x="sepal_length", y="petal_length", data=iris);

# %%
#sns.pairplot(data=iris, hue="species");

# %%
#dots = sns.load_dataset("dots")

# %%
#sns.relplot(x= "time", y= "firing_rate", col="align",
#            hue="choice", kind="line", data=dots);

# %%
#sns.relplot(x= "time", y="firing_rate", col="choice",
#hue="align", kind="scatter", data=dots);

# %%
#sns.relplot(x= "coherence", y="firing_rate", col="choice",
#            hue="align", kind="scatter", data=dots);

# %% [markdown]
# ### Reference
#
# http://seaborn.pydata.org/api.html
