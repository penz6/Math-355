# %% [markdown]
# # **Module 1: Programming Fundamentals for Machine Learning**
#
# ### **Prepared by**: Dr. Hum Nath Bhandari, Department of Mathematics, RWU
#
# ### **Course**: MATH 355/COMSC 415-Machine Learning
#
# ### **Notebook2**: Basic Python Tutorial

# %% [markdown]
# ## **Learning Outcomes**
#
# In this notebook, we will learn basic data structures and operations in Python. Topics includes:
#
# - Printing in Python
#
# - Python as a calculator
#
# - Creating variables in Python
#
# - Reserved keywords for Python
#
# - Basic python data structures: numbers, boolean, strings, list, tuple, dictionary
#
# - Writing user defined functins in Python
#
# - Random numbers generators
#
# - Conditional statements
#
# - Loop operations in Python
#
# - Formatting in Python
#
# - Reading and writing files in Python

# %% [markdown]
# ## **Printing in Python**

# %%
print('Lets learn Python Basics!')

#print("\n") # printing blank line
#print("Python is incredible!!")
# Out:
# Lets learn Python Basics!

# %% [markdown]
# ## **Python as a Calculator**
#
# We can perform basic calculations in Python such as addition, subtraction, multiplication, division, integer division, etc.

# %%
7 + 9
# Out:
# 16

# %%
6+ 7*8
# Out:
# 62

# %%
(50 - 5*6) / 4
# Out:
# 5.0

# %%
22 / 7
# Out:
# 3.142857142857143

# %%
22//7  #floor division diqscards the fractional part
# Out:
# 3

# %%
3**2  # squared
# Out:
# 9

# %%
10%2 # reminder operation
# Out:
# 0

# %%
13%3
# Out:
# 1

# %% [markdown]
# ### **Order of Operations**
#
#
# Python follows **PEMDAS(P = parenthesis, E = exponent, M = multiplication, D= Division, A= Addition, S= Subtraction)** convention of Mathematics.

# %%
#2*(3-1)

# %%
#(1+1)**(5-2)

# %%
#2**1+1 #is not 4

# %%
#3*1**3 # is not 27

# %%
#6+4/2 # is not 5

# %% [markdown]
# ## **Creating Variables**
#
# Python variable names can be arbitrary long. They may contain both letters and numbers but they have to begin with a letter. Underscore character ( _ ) can be used. We cannot use special characters such as @,$, &, etc while defining variables.

# %%
#Illegal variables
12my_variable, more@

# %%
#legal variables
my_var = 12
second_var_123 = 89

# %%
width = 40  
length = 5
Area = width * length
Area

# %% [markdown]
# ## **Reserved Keywords for Python**
#
# There are few words which are reserved for Python language. Therefore, users should avoid using these reserved words. For example:
#
# **and, del, from, not, while, as, elif, global, or, with, assert, else, if, pass, yield, break, except, import, print, class, exec, raise, continue, finally, is, return, def, for, lambda,  try, in**, etc

# %% [markdown]
# ## **Basic Python Variable Types**
#
# There are several variable types in Python. Here is a list of the most common types:
#
# - **int**:  integer
# - **float**: floating point numbers (decimal numbers)
# - **complex**: complex numbers
# - **bool**: boolean types (True, False)
# - **str**: string

# %%
#integer
type(13)
# Out:
# int

# %%
#float (decimal numbers) 
type(10.5)
# Out:
# float

# %%
#complex number
type(5j)
# Out:
# complex

# %%
complex(2,3)
# Out:
# (2+3j)

# %%
z = 2-3j

# %%
z.real

# %%
z.imag

# %%
#boolean
a = True
type(a)
# Out:
# bool

# %% [markdown]
# ### **String**
# Besides numbers, Python can also manipulate strings, which can be expressed in several ways. They can be enclosed in single quotes ('  ') or double quotes (" ") with the same result.

# %%
course_name = 'Machine Learning'

# %%
semester = 'Fall 2022'

# %%
myclass = course_name + ' ' + semester

# %%
myclass
# Out:
# 'Machine Learning Fall 2022'

# %%
type(myclass)
# Out:
# str

# %%
myclass[0] # to access first character of the string
# Out:
# 'M'

# %%
myclass[:]
# Out:
# 'Machine Learning Fall 2022'

# %%
myclass[:-1]
# Out:
# 'Machine Learning Fall 202'

# %%
myclass + myclass
# Out:
# 'Machine Learning Fall 2022Machine Learning Fall 2022'

# %%
"Speed Limit "+ 65
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-010668e10db1> in <module>()
# ----> 1 "Speed Limit "+ 65
#
# TypeError: can only concatenate str (not "int") to str

# %%
"Speed Limit "+ str(65)
# Out:
# 'Speed Limit 65'

# %% [markdown]
# ## **Additional Core Python Data Types**
# - **list**:  Ordered Array
# - **tuple**: Ordered Immutable Array
# - **dict**: Unordered list of keys and values

# %% [markdown]
# ### **List**
#
# The Python lists are positionally ordered collection of aribitrarily typed objects with no fixed size. They are also mutable, meaning lists can be modified. They provide a flexible tool for representing aribitrary collections such as lists of files, emplyees in a company, emails in your inbox, and so on.

# %%
a = [ ] #one way to create empty list
type(a)
# Out:
# list

# %%
a = list()  # another way to create empty list
type(a)
# Out:
# list

# %%
x = [1, 'RWU', 2, 'Bristol', True]
#type(x)
x
# Out:
# [1, 'RWU', 2, 'Bristol', True]

# %% [markdown]
# #### **Basic List Operations**

# %%
x = [1,2,3]

len(x)  # length
# Out:
# 3

# %%
x + [5,6,7] # concatenation
# Out:
# [1, 2, 3, 5, 6, 7]

# %%
y = [2, 'Math', 5, "Machine  Learning"]

x+y
# Out:
# [1, 2, 3, 2, 'Math', 5, 'Machine  Learning']

# %%
["SPAM"]*5 # Repetition
# Out:
# ['SPAM', 'SPAM', 'SPAM', 'SPAM', 'SPAM']

# %% [markdown]
# ####  **List Indexing and Slicing**

# %%
x = [1, 'RWU', 2, 'Bristol']
x
# Out:
# [1, 'RWU', 2, 'Bristol']

# %%
x[0]
# Out:
# 1

# %%
x[2]
# Out:
# 2

# %%
x[1:]
# Out:
# ['RWU', 2, 'Bristol']

# %%
x[:-1]
# Out:
# [1, 'RWU', 2]

# %% [markdown]
# #### **Some Built-in functions on List Object**
#
# - extend()
#
# - append()
#
# - sort()
#
# - reverse()
#
# - del()
# - count()
# - copy()
# - clear()
# - remove()
# - insert(i, X)

# %%
#x = [1, 'RWU', 2, 'Bristol']

my_friends = [ ]
my_friends = ['Josh', 'Sophia']
print(my_friends)
my_friends.append('Nancy')
my_friends.extend(['Colton', 'Bob'])

my_friends

my_friends.remove('Bob')

#x.extend([23,78]) # it changes original variable too
#x
# Out:
# ['Josh', 'Sophia']

# %%
x = [3,1,6,8]
x.sort()
x
# Out:
# [1, 3, 6, 8]

# %%
x.sort()

# %%
a = []

a.append(30) # it changes original variable too
a
# Out:
# [30]

# %%
a.append("grade")
a
# Out:
# [30, 'grade', 'grade']

# %%
a.append(80)
a
# Out:
# [30, 'grade', 'grade', 80]

# %%
a[0] = 70
a

# %%
L = [123, 'spam', 1.23]
L
# Out:
# [123, 'spam', 1.23]

# %%
del(L[0]) # it changes original variable too

L
# Out:
# ['spam', 1.23]

# %%
M = ['bb', 'aa', 'cc']
M.sort() # it changes  original variable too
M
# Out:
# ['aa', 'bb', 'cc']

# %%
M.reverse() #it changes original variable too
M
# Out:
# ['cc', 'bb', 'aa']

# %%
N = M.copy()
N
# Out:
# ['cc', 'bb', 'aa']

# %%
N.clear()
N
# Out:
# []

# %%
M.remove('cc')
M
# Out:
# ['bb', 'aa']

# %%
M.insert(0,"cc")
M
# Out:
# ['cc', 'bb', 'aa']

# %% [markdown]
# #### **List Iterations and Comprehensions**

# %%
1 in  [1,2,3] # checking for list membership

# %%
0 in [1,5,9]
# Out:
# False

# %%
for x in [1,2,3]:
    print(x)
# Out:
# 1
# 2
# 3

# %%
squares = [x**2 for x in [1,2,4]] # list comprehensions

# %%
squares
# Out:
# [1, 4, 16]

# %% [markdown]
# #### **Nested Lists and Slicing**

# %%
matrix = [ [1,2,3], [4,5,6],[7,8,9]  ]
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[1]
# Out:
# [4, 5, 6]

# %%
matrix[-1]
# Out:
# [7, 8, 9]

# %%
matrix[0][0]
# Out:
# 1

# %%
matrix[2][0]
# Out:
# 7

# %%
matrix[2][0] = 10
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [10, 8, 9]]

# %%
matrix[1][0]
# Out:
# 4

# %% [markdown]
# ### **Tuple**
#
# Tuples are immutable lists. Pretty much anything you can do to a list that does not involve modifying it, you can do to a tuple. You specify a tuple by using parentheses (or nothing) instead of square brackets.

# %%
my_list = [1,2,3]

my_tuple = (1,2,3)

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list[0] = 50
my_list
# Out:
# [50, 2, 3]

# %%
my_tuple
# Out:
# (1, 2, 3)

# %%
my_tuple[0] = 50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-a8dc1ca4f94f> in <module>()
# ----> 1 my_tuple[0] = 50
#
# TypeError: 'tuple' object does not support item assignment

# %%
other_tuple[0]

# %%
my_tuple[0] = 30 # not possible

# %%
my_tuple + (3,4,7,6) #concatenation of tuple

# %% [markdown]
# Tuples are a convenient way to return multiple values from functions.

# %%
def sum_and_product(x,y):
    return (x+y), x*y

s,p = sum_and_product(3,8)
s,p

# %% [markdown]
# Tuples can also be used for multiple assigment:

# %%
x,y = 1,2
x,y = y,x # easy way to swap variables in python!

# %% [markdown]
# ### **Dictionary**
#
# Dictionaries are unordered and changeable collections of Python objects. In Python, dictionaries are written with curly brackets, and they have **keys** and **values**.

# %%
my_dictionary = { }

# %%
my_dictionary = {'name': 'John', 'grade': 90,  'course': 'Scientific Computing'}
my_dictionary

# %%
type(my_dictionary)

# %%
my_dictionary.keys()

# %%
my_dictionary.values()

# %%
my_dictionary.items()

# %%
my_dictionary['name']

# %%
my_dictionary['grade']

# %% [markdown]
# Creating dictionary from scratch

# %%
D = { } # one way to create an empty dictionary
type(D)

# %%
D = dict() # another way to create an empty dictionary
D

# %%
D['name'] = "Josh"

D['job'] = "Project Manager"
D['age'] = 20
D

# %%
for k in D.keys():
    print(k)

# %%
for k,v in D.items():
    print(k,v)

# %% [markdown]
# #### **Creatig Disctionay from List using Zip function**

# %%
D = dict(zip(['a', 'b', 'c'], [1,2,3])) # zip together keys and values
D

# %% [markdown]
# ## **Writing User Defined Functions in Python**
# Creating new functions in Python is easy. We use function to maximize code reuse and minimize redundancy.

# %%
def find_sum(x,y):
    return x+y

# %%
x = 45
y = 50


find_sum(x,y)# implementation of functions

# %%
x  =  10
y = 20

find_sum(x,y)

# %%
#another way of writing function
def find_sum(x, y):
    z = x+y
    return z

# %%
find_sum(4,8)

# %%
find_sum(100, 1009)

# %%
def fahrenheit(T): # takes temperature in celcius and converts in fahrenheit
    return (9/5)*T + 32

def celsius(T):  # takes temperature in fahrenheit and converts in celcius 
    return (5/9)*(T-32)

# %%
celsius(32)

# %%
fahrenheit(0)

# %% [markdown]
# ### **Creating function using Lambda Keyword**

# %%
add = lambda x, y : x + y

# %%
add(4,8)

# %%
fahrenheit =  lambda x: (9/5)*x + 32
celsius = lambda x:  (5/9)*(x-32)

# %%
fahrenheit(45)

# %% [markdown]
# ## **Built in Math Library**

# %%
import math

# %% [markdown]
# #### **Basic Math Functions in Python**
# - fabs(x)
# - ceil(x)
# - floor(x)
# - exp(x)
# - log(x)# natural logarithm
# - log10(x)
# - max(x1, x2,...)
# - pow(x, y)
# - round(x [,n]) # round to n digits from the decimal points
# - sqrt(x)
# - sin(x)
# - cos(x)
# - tan(x)

# %%
abs(-4.8)

# %%
math.fabs(-4.8)

# %%
math.ceil(-4.6)

# %%
math.log(8) # natural log

# %%
math.pow(2,3)

# %%
2**3

# %%
round(3.413894, 3)

# %%
math.sqrt(9)

# %%
math.sin(math.pi/2)

# %%
math.tan(math.pi/4)

# %% [markdown]
# ## **Generating Random Numbers in Python**

# %%
import random

a = random.random( ) # creates random number between 0 and 1
a

# %%
b = random.uniform(1, 7) # creates a random number between 1 and 7 from uniform distribution
b

# %%
c = random.randint(1, 10) # creates a random integer between 1 and 10
c

# %%
items = [1, 2, 3, 4, 5, 6, 7,8,9]

random.shuffle(items) # random reshuffling
items

# %%
random.sample([1, 2, 3, 4, 5,6,7,8], 4) # random sampling from given list

# %% [markdown]
# ## **Conditional Statements in Python**
#
# ### **if else statement**

# %%
x = 10;
if x > 0:
    print("x is positive")
    print("Done")

# %%
grade = 50;

if grade >= 60:
    
    print("You passed this class")
else:
    print("Sorry you are failed! Please repeate this course in the next semester!")

# %% [markdown]
# ### **Chained Conditional Statements**

# %%
x = 2; y = 8

if x < y:
    print("x is less than y")
elif(x > y):
    print("x is greater than y")
else:
    print("x and y are equal")

# %%
grade = 66

if grade >= 90:
    print("A")
elif grade >= 80:
    print("B")
elif grade >= 70:
    print("C")
elif grade >=60: 
    print("D")
else:
    print("Sorry you are failled in this class")

# %%
x = 2
x == 2

# %% [markdown]
# ### **Nested Conditional Statements**

# %%
x = 4; y = 7;

if x == y:
    print("x and y are equal")
    
else:
    
    if x< y:
        print ("x is less than y")
    else:
        print("x is greater than y")

# %% [markdown]
# ## **Loop Operations in Python**

# %% [markdown]
# ### **for loop**

# %%
for i in [1,2,3,4,5,6]:
    print(i)

# %%
###  **While Loop**

# %%
i = 0

while i < 6:
    print(i)
    i+=1 # i = i+1

# %% [markdown]
# ### **range function**
#
# - range(stop)
#
# - range(start, stop, step)

# %%
for i in range(6):
    print(i)

# %%
for i in range(1,6):
    print(i)

# %%
for i in range(1,6,2): # 
    print(i)

# %%
[x**2 for x in range(0, 8, 2)]

# %% [markdown]
# ## **Formatting in Python**

# %%
print("pi =%d" % (3.14159))
print("pi =%.2f" % (3.14159))
#print("pi =%.4f" % (3.14159))
print("pi =%s" % (3.14159))
print('{:}, {:.2f}, {:s}'.format(26, 3.141593, "python"))

# %% [markdown]
# ### **Formating Date Time**

# %%
import datetime
d = datetime.datetime(2010, 7, 4, 12, 15, 58)
'{:%Y-%m-%d %H:%M:%S}'.format(d)

# %% [markdown]
# ## **File I/O**
#
# ### **Raw Input in Python**

# %%
name = input("Tell me your name: ")
print("Hello " + name + "!")
age = input("How old are you? ")
print("You are " + age + " years old, " + name + "!")

# %%
a = input("Enter your grade:")

# %%
a + 45 #input will be taken as characters

# %%
float(a) + 45

# %% [markdown]
# ### **Reading/Writing Files in Python**
#
# We will discuss about this topics in upcomming Notebooks. See the following liks for references:
#
# - [Files I/O](https://www.tutorialspoint.com/python/python_files_io.htm)
# - [Reading and Writing in Python](https://www.geeksforgeeks.org/reading-writing-text-files-python/)

# %% [markdown]
# ## **References**
#
#
# There are several resourses available to study python, including the following online turorials.
#
# - [Python Documentation](https://docs.python.org/3/tutorial/)
# - [Tutorialpoint](https://www.tutorialspoint.com/python/python_overview.htm)
