# %% [markdown]
# # **Module 3: Overview of Data Science and Machine Learning**
#
# ### **Instructor**: Dr. Hum Nath Bhandari, Department of Mathematics and Physics, RWU
#
# ### **Course**: MATH355/COMSC 415-Machine Learning
#
# ### **Quiz 3**:  Exploring Real World Regression Problems

# %% [markdown]
# ### **Your Name:**

# %% [markdown]
# ## **Quiz Question and Instructions (Part I: 50 points):**
#
#
# - Use **Lecture Notes 4** to find few links for Data Scources to explore several application problems which can be freamed as regression problems. You may explore additional sources of data in order to develop even broader application perspectives of Machine Learning.
#
# - Idendity the most interesting and feasible problem and corresponding dataset based on your exploration.
#
# - Perform a decent research on different aspects of the data such as number of features(variables), number of observations(total rows), types of variables, overall size of the data.
#
# - Understand the real world implications/benefits of possible model predictions on this data.
#
# - If you think that it is a feasible problm to work in a short period of time (DONOT choose highly complex and time consuming problem), then perform the following:
#
#    - Download the dataset and upload one version in Google Drive. Attach a link of data in this jupyter notebook. For consistency, use data path as follows: MyDrive/Machine_Learning/Regression_Models/Data/name_of_data.csv
#
#    - Write a summary report providing the answers of following questions(at the minimum).
#
#       * A paragraph which provides problem overview(Abstract).
#       * Make a list of most suitable predictors (input features) and also provide possible target variable.
#       * What types of machine learning models have been used in this data. Make a list few example models.
#       * Load the data in this jupyter notebook and perform initial explratioin and visualization of various aspects.
#       * Perform data manuplation and data cleaning
#
# - Submit your report(jupyter notebook) on Bridges before the deadline.

# %% [markdown]
# #### Abstract
# The problem that I am looking at is the cost of houses based on various factors, including square footage, number of rooms, and the location of the house. This problem has real world applications, such as esitmating the price to list a house at, or seeing if a house that you are planning to buy is priced fairly. This is a real world problem that we have firm data for, as well as new data that is coming in every day, if we wanted to compare our model to real world data and see how accurate it is.
#
# #### Best Predictors
# Best inputs:
# - Area
# - Bathroooms
# - Bedrooms
# - Location
#
# And what we should use for the prediction:
# - Price
#
# #### What Other Models Have Been Used?
#  - Linear Regression
#  - Random Forest
#
#
#  #### Data Link
#
#  https://drive.google.com/file/d/1QImjV5viVN-Zrjmj3cZUaG-KRzSH7JAO/view?usp=sharing

# %%
import pandas as pd
import matplotlib.pyplot as plt

# lead and display dataset
df = pd.read_csv("Housing.csv")

print("Head of Dataframe:")
print(df.head())

print("Stats about Data:")
print(df.describe())

#visualize the data
plt.scatter(df['area'], df['price'])
plt.xlabel('Area (sq ft)')
plt.ylabel('Price ($)')
plt.title('Area vs Price')
plt.show()
#visualize the data
plt.scatter(df['bedrooms'], df['price'])
plt.xlabel('Number of Bedrooms')
plt.ylabel('Price ($)')
plt.title('Bedrooms vs Price')
plt.show()
#visualize the data
plt.scatter(df['bathrooms'], df['price'])
plt.xlabel('Number of Bathrooms')
plt.ylabel('Price ($)')
plt.title('Bathrooms vs Price')
plt.show()
#visualize the data
plt.scatter(df['mainroad'], df['price'])
plt.xlabel('Connected to Main Road')
plt.ylabel('Price ($)')
plt.title('Location vs Price')
plt.show()

#clean the data
df = df.dropna()
# Out:
# Head of Dataframe:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
# Stats about Data:
# ...
